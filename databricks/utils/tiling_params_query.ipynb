# %%
# %sql
SELECT
  siteId,
  ingestRunId,
  tileSizeM,
  hotTileThreshold,
  targetPointsPerBucket,
  saltBuckets,
  maxTilePoints,
  computedAt
FROM delta.`abfss://aggregated@trimblegeospatialdemo.dfs.core.windows.net/control/tiling_params`
WHERE siteId = 'wellington_cbd'
  AND ingestRunId = '20130101'
ORDER BY computedAt DESC
LIMIT 1
