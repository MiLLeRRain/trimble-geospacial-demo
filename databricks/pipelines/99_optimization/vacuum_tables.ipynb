# %%
# %sql
USE CATALOG main;
USE SCHEMA demo;

VACUUM points_raw RETAIN 168 HOURS;
VACUUM processed_points_tiled_v2 RETAIN 168 HOURS;
VACUUM surface_cells_v2 RETAIN 168 HOURS;
VACUUM surface_patches_v2 RETAIN 168 HOURS;
VACUUM features_water_bodies_v2 RETAIN 168 HOURS;
VACUUM features_building_candidates_v2 RETAIN 168 HOURS;
