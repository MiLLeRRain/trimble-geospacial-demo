# %%
# %sql
USE CATALOG main;
USE SCHEMA demo;

ANALYZE TABLE points_raw COMPUTE STATISTICS;
ANALYZE TABLE processed_points_tiled_v2 COMPUTE STATISTICS;
ANALYZE TABLE tile_stats_v2 COMPUTE STATISTICS;
ANALYZE TABLE surface_cells_v2 COMPUTE STATISTICS;
ANALYZE TABLE surface_patches_v2 COMPUTE STATISTICS;
ANALYZE TABLE features_water_bodies_v2 COMPUTE STATISTICS;
ANALYZE TABLE features_building_candidates_v2 COMPUTE STATISTICS;
