# %%
# %sql
USE CATALOG main;
USE SCHEMA demo;

-- =========================
-- RAW / PROCESSED
-- =========================
OPTIMIZE points_raw
ZORDER BY (siteId, tileId);

OPTIMIZE processed_points_tiled_v2
ZORDER BY (siteId, tileId);

-- =========================
-- AGGREGATION
-- =========================
OPTIMIZE tile_stats_v2
ZORDER BY (siteId, tileId);

-- =========================
-- SURFACE
-- =========================
OPTIMIZE surface_cells_v2
ZORDER BY (siteId, tileId);

OPTIMIZE surface_patches_v2
ZORDER BY (siteId, tileId);

-- =========================
-- FEATURES
-- =========================
OPTIMIZE features_water_bodies_v2
ZORDER BY (siteId, waterBodyId);

OPTIMIZE features_building_candidates_v2
ZORDER BY (siteId, tileId);
